# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('../files/AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
# Which hosts are the busiest and why
host_count = air_bnb[['host_name', 'id']].groupby('host_id').count()
host_count.sort_values('id', ascending=False)
# show that the top host owning 327 airbnbs is host_id 219517861, 107434423, 30283594, 137358866, 16098958

# Checking host_id 219517861
bnb_copy = air_bnb
# bnb_copy.set_index('host_id',inplace = True)
# bnb_copy

# maybe make bin with ranks of numbers of airbnbs

bnb_copy.loc[[219517861, 107434423, 30283594, 137358866, 16098958]]
# Out:
#                  id                                               name  \
# host_id
# 219517861  30181691      Sonder | 180 Water | Incredible 2BR + Rooftop
# 219517861  30181945         Sonder | 180 Water | Premier 1BR + Rooftop
# 219517861  30347708        Sonder | 180 Water | Charming 1BR + Rooftop
# 219517861  30937590            Sonder | The Nash | Artsy 1BR + Rooftop
# 219517861  30937591        Sonder | The Nash | Lovely Studio + Rooftop
# ...             ...                                                ...
# 16098958   33070416          Prime 1 bedroom Doorman Gym RoofDeck 5221
# 16098958   33071794         Prime Location 44stDoorman Gym Studio!5217
# 16098958   33072686       Prime Location One Bed Doorman Gym Deck!5223
# 16098958   33072804  34th and 6th Ave - Doorman Gym Roofdeck 1 bed ...
# 16098958   33339676    Sunny Large Studio Elevator Doorman Gym UN 5226
#
#                 host_name neighbourhood_group       neighbourhood  latitude  \
# host_id
# 219517861    Sonder (NYC)           Manhattan  Financial District  40.70637
# 219517861    Sonder (NYC)           Manhattan  Financial District  40.70771
# 219517861    Sonder (NYC)           Manhattan  Financial District  40.70743
# 219517861    Sonder (NYC)           Manhattan         Murray Hill  40.74792
# 219517861    Sonder (NYC)           Manhattan         Murray Hill  40.74771
# ...                   ...                 ...                 ...       ...
# 16098958   Jeremy & Laura           Manhattan             Midtown  40.74885
# 16098958   Jeremy & Laura           Manhattan             Midtown  40.75032
# 16098958   Jeremy & Laura           Manhattan      Hell's Kitchen  40.76291
# 16098958   Jeremy & Laura           Manhattan             Midtown  40.74909
# 16098958   Jeremy & Laura           Manhattan             Midtown  40.75191
#
#            longitude        room_type  price  minimum_nights  \
# host_id
# 219517861  -74.00645  Entire home/apt    302              29
# 219517861  -74.00641  Entire home/apt    229              29
# 219517861  -74.00443  Entire home/apt    232              29
# 219517861  -73.97614  Entire home/apt    262               2
# 219517861  -73.97528  Entire home/apt    255               2
# ...              ...              ...    ...             ...
# 16098958   -73.98698  Entire home/apt    260              30
# 16098958   -73.97143  Entire home/apt    175              30
# 16098958   -73.98750  Entire home/apt    250              30
# 16098958   -73.98657  Entire home/apt    170              30
# 16098958   -73.96980  Entire home/apt    140              30
#
#            number_of_reviews last_review  reviews_per_month  \
# host_id
# 219517861                  0         NaN                NaN
# 219517861                  1  2019-05-29               0.73
# 219517861                  1  2019-05-21               0.60
# 219517861                  8  2019-06-09               1.86
# 219517861                 14  2019-06-10               2.59
# ...                      ...         ...                ...
# 16098958                   1  2019-05-06               0.46
# 16098958                   0         NaN                NaN
# 16098958                   0         NaN                NaN
# 16098958                   1  2019-05-12               0.51
# 16098958                   0         NaN                NaN
#
#            calculated_host_listings_count  availability_365
# host_id
# 219517861                             327               309
# 219517861                             327               219
# 219517861                             327               159
# 219517861                             327                91
# 219517861                             327                81
# ...                                   ...               ...
# 16098958                               96               343
# 16098958                               96               342
# 16098958                               96               303
# 16098958                               96               345
# 16098958                               96               311
#
# [879 rows x 15 columns]

# %%
# How many neighborhood groups are available and which shows up the most?

# %%
# Are private rooms the most popular in manhattan?

# %%
# Which hosts are the busiest and based on their reviews?

# %%
#Which neighorhood group has the highest average price?

# %%
# Which neighbor hood group has the highest total price?

# %%
#Which top 5 hosts have the highest total price?

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

# %%
# What host has the highest total of prices and where are they located?

# %%
# When did Danielle from Queens last receive a review?

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %% [markdown]
# 2. How many listings have completely open availability?

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
